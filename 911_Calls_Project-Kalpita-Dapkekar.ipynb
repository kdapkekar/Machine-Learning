# %% [markdown]
# # 911 Calls Project

# %% [markdown]
# For this capstone project we will be analyzing some 911 call data. The data contains the following fields:
#
# * lat : String variable, Latitude
# * lng: String variable, Longitude
# * desc: String variable, Description of the Emergency Call
# * zip: String variable, Zipcode
# * title: String variable, Title
# * timeStamp: String variable, YYYY-MM-DD HH:MM:SS
# * twp: String variable, Township
# * addr: String variable, Address
# * e: String variable, Dummy variable (always 1)

# %% [markdown]
# ## Data and Setup

# %% [markdown]
# **Import numpy and pandas**

# %%
import numpy as np
import pandas as pd
from matplotlib.dates import DateFormatter

# %% [markdown]
# **Import visualization libraries and set %matplotlib inline.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# **Read in the csv file as a dataframe called df**

# %%
df = pd.read_csv('C:/Users/Dell/AMAT Projects/911.csv')
df
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# ...

# %% [markdown]
# **Check the info() of the df**

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
# lat          99492 non-null float64
# lng          99492 non-null float64
# desc         99492 non-null object
# zip          86637 non-null float64
# title        99492 non-null object
# timeStamp    99492 non-null object
# twp          99449 non-null object
# addr         98973 non-null object
# e            99492 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %% [markdown]
# **Check the head of df (first 3 rows)**

# %%
df.head(3)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1
# 2                    HAWS AVE  1

# %% [markdown]
# ## Basic Questions

# %% [markdown]
# **Show the top 5 zipcodes for 911 calls**

# %%
df_res = df.groupby('zip').count()
df_top_5_zipcodes = df_res.sort_values(['lat'],ascending=False).head()
df_top_5_zipcodes = df_top_5_zipcodes.reset_index()
df_top_5_zipcodes1 = df_top_5_zipcodes[['zip','lat']]
print(df_top_5_zipcodes1.to_string(index=False,header = False))
# Out:
#  19401.0  6979
#  19464.0  6643
#  19403.0  4854
#  19446.0  4748
#  19406.0  3174

# %% [markdown]
# **Show the top 5 townships (twp) for 911 calls**

# %%
df_top_5_township = df.groupby('twp').count()
df_top_5_township = df_top_5_township.sort_values(['lat'],ascending=False).head()
df_top_5_township = df_top_5_township.reset_index()
df_top_5_township1 = df_top_5_township[['twp','lat']]
print(df_top_5_township1.to_string(index=False,header = False))
# Out:
#  LOWER MERION  8443
#      ABINGTON  5977
#    NORRISTOWN  5890
#  UPPER MERION  5227
#    CHELTENHAM  4575

# %% [markdown]
# **Take a look at the 'title' column, how many unique title codes are there?**

# %%
codes = df.title.unique()
len(codes)
# Out:
# 110

# %% [markdown]
# ## Creating new features

# %% [markdown]
# **In the titles column there are "Reasons/Departments" specified before the title code. These are EMS, Fire, and Traffic. Use .apply() with a custom lambda expression to create a new column called "Reason" that contains this string value.**
#
# *For example, if the title column value is EMS: BACK PAINS/INJURY , the Reason column value would be EMS.*

# %%
df['Reasons'] = df.apply(lambda x : x['title'].split(':')[0],axis=1)

# %% [markdown]
# **Count 911 calls based off of this new column by Reason**

# %%
df_reasons = df.groupby('Reasons').count()
df_reasons=df_reasons.sort_values(['lat'],ascending=False).head()
df_reasons= df_reasons.reset_index()
df_reasons1 = df_reasons[['Reasons','lat']]
print(df_reasons1.to_string(index=False,header = False))
# Out:
#      EMS  48877
#  Traffic  35695
#     Fire  14920

# %% [markdown]
# **Use seaborn to create a countplot of 911 calls by Reason.**

# %%
ax = sns.countplot(x="Reasons",data = df)

# %% [markdown]
# **Show the data type of the objects in the timeStamp column?**

# %%
type(df.loc[0,'timeStamp'])
# Out:
# str

# %% [markdown]
# **These timestamps are still strings. Use [pd.to_datetime](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) to convert the column from strings to DateTime objects.**

# %%
df['timeStamp'] = pd.to_datetime(df['timeStamp'])

# %% [markdown]
# **You can now grab specific attributes from a Datetime object by calling them. For example:**
#
#     time = df['timeStamp'].iloc[0]
#     time.hour
#
# **You can use Jupyter's tab method to explore the various attributes you can call. Now that the timestamp column are actually DateTime objects, use .apply() to create 3 new columns called Hour, Month, and Day of Week. You will create these columns based off of the timeStamp column.**

# %%
time = df['timeStamp'].iloc[0]
print(time.hour)
print(time.minute)
print(time.second)
print(time.month)
print(time.day)
print(time.year)

df['Hour'] = df.apply(lambda x: x['timeStamp'].hour, axis=1)
df['Month'] = df.apply(lambda x: x['timeStamp'].month, axis=1)
df['Day'] = df.apply(lambda x: x['timeStamp'].weekday(), axis=1)
# Out:
# 17
# 40
# 0
# 12
# 10
# 2015

# %% [markdown]
# **The Day of Week is an integer 0-6. Use the .map() with this dictionary to map the actual string names to the day of the week:**
#
#     dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['Day'] = df['Day'].map(dmap)

# %% [markdown]
# **Use seaborn to create a countplot of the Day of Week column with the hue based off of the Reason column.**

# %%
ax = sns.countplot(x="Day",hue="Reasons",data = df)

# %% [markdown]
# **Now do the same for Month:**

# %%
ax = sns.countplot(x="Month",hue="Reasons",data = df)

# %% [markdown]
# **You should have noticed it was missing some Months, we fill in this information by plotting the information with a simple line plot that fills in the missing months**

# %% [markdown]
# **Now create a gropuby object called byMonth, where you group the DataFrame by the month column and use the count() method for aggregation. Use the head() method to show the head of this returned DataFrame.**

# %%
df_month = df.groupby('Month').count()
df_month1=df_month.sort_values(['Month'],ascending=True).head()
df_month1
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Month
# 1      13205  13205  13205  11527  13205      13205  13203  13096  13205
# 2      11467  11467  11467   9930  11467      11467  11465  11396  11467
# 3      11101  11101  11101   9755  11101      11101  11092  11059  11101
# 4      11326  11326  11326   9895  11326      11326  11323  11283  11326
# 5      11423  11423  11423   9946  11423      11423  11420  11378  11423
#
#        Reasons   Hour    Day
# Month
# 1        13205  13205  13205
# 2        11467  11467  11467
# 3        11101  11101  11101
# 4        11326  11326  11326
# 5        11423  11423  11423

# %% [markdown]
# **Now create a simple plot off of the dataframe with .plot() indicating the count of calls per month.**

# %%
plt.plot(df_month[['lat']])
plt.tight_layout()

# %% [markdown]
# **Use seaborn's lmplot() to create a linear fit on the number of calls per month. You may need to reset the index to a column.**

# %%
df_month2 = df_month.reset_index()
df_month2
ax = sns.lmplot(x = 'Month', y = 'twp', data = df_month2)

# %% [markdown]
# **Create a new column called 'Date' that contains the date from the timeStamp column. You'll need to use apply along with the .date() method.**

# %%
df['Date'] = df.apply(lambda x: (x['timeStamp'].date()), axis = 1)

# %% [markdown]
# **Groupby this Date column with the count() aggregate and create a plot of counts of 911 calls.**

# %%
df_1 = df.groupby('Date').count()
df_1 = df_1.sort_values(['Date'],ascending=True)


fig, ax = plt.subplots()
ax.plot(df_1[['lat']])
ax.set_xlim([datetime.date(2015, 12, 10), datetime.date(2016, 8, 24)])
ax.xaxis.set_major_formatter(DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(MonthLocator())
plt.tight_layout()

# %% [markdown]
# **Recreate this plot but create 3 separate plots with each plot representing a Reason for the 911 call. Title the plot. Use plt.tight_layout() to adjust the axis**

# %%
df_Traffic = df[df.Reasons.eq('Traffic')]
df_Traffic = df_Traffic.groupby('Date').count()
df_Traffic = df_Traffic.sort_values(['Date'],ascending=True)


fig, ax = plt.subplots()
ax.plot(df_Traffic[['lat']])
ax.set_title("Traffic")
ax.set_xlim([datetime.date(2015, 12, 10), datetime.date(2016, 8, 24)])
ax.xaxis.set_major_formatter(DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(MonthLocator())
plt.tight_layout()

# %%
import datetime
df_Fire = df[df.Reasons.eq('Fire')]
df_Fire = df_Fire.groupby('Date').count()
df_Fire = df_Fire.sort_values(['Date'],ascending=True)


fig, ax = plt.subplots()
ax.plot(df_Fire[['lat']])
ax.set_title("Fire")
ax.set_xlim([datetime.date(2015, 12, 10), datetime.date(2016, 8, 24)])
ax.xaxis.set_major_formatter(DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(MonthLocator())
plt.tight_layout()

# %%
from matplotlib.dates import MonthLocator, DateFormatter
df_EMS = df[df.Reasons.eq('EMS')]
df_EMS = df_EMS.groupby('Date').count()
df_EMS1 = df_EMS.reset_index()
df_EMS = df_EMS.sort_values(['Date'],ascending=True)


fig, ax = plt.subplots()
ax.plot(df_EMS[['lat']])
ax.set_title("EMS")
ax.set_xlim([datetime.date(2015, 12, 10), datetime.date(2016, 8, 24)])
ax.xaxis.set_major_formatter(DateFormatter('%b %Y'))
ax.xaxis.set_major_locator(MonthLocator())
plt.tight_layout()
